# %%
import numpy as np
import math
from matplotlib import pyplot as plt
import itertools
import sys

n = 30 
np.random.seed(3)
xs = np.random.uniform(size = 30)
xs = np.sort(xs)

ys = 4*np.sin(math.pi*xs)*np.cos(6*math.pi*xs**2) 

training_output = ys +  np.random.uniform(0,1, size = 30)

plt.plot(xs,ys)

# %%
def kernelRidgeRegression(K, X_labels, reg_lambda = 0):
    # TODO: polyfeature + normalization?
    n = K.shape[0]
    assert K.shape[0] == K.shape[1], "incorrect kernel shape"
    return np.linalg.inv(K+reg_lambda*np.eye(n)).dot(X_labels)

def predict(K, alpha):
    n = K.shape[0]
    if len(K.shape) == 1: # one kernel value
        y = np.sum(alpha.dot(K))
        return y
    else: # kernel matrix
        ys = np.zeros(n)
        for i in range(n):
            ys[i] = np.sum(alpha.dot(K[i]))
        return ys
def poly_kernel(X, d):
    if len(X.shape) < 2:  # fir n x 1 data
        X = np.expand_dims(X, axis = 1)
    n = X.shape[0]
    K = np.zeros((n,n))
    for i in range(n):
        for j in range(n):
            K[i][j] = np.power(1+ X[i].T.dot(X[j]), d)
    return K

def rbf_kernel(X, gamma):
    n = X.shape[0]
    K = np.zeros((n,n))
    assert gamma > 0, "gamma should be larger than 0"
    for i in range(n):
        for j in range(n):
            if len(X.shape) == 2:
                K[i][j] = np.exp(-gamma * np.linalg.norm(X[i]-X[j], 2 ))
            else: # for  n x 1 data input
                K[i][j] = np.exp(-gamma * np.absolute(X[i]-X[j]))
    return K

# %%
# A3 a
# grid search parameters for rbf kernel
rbf_d = dict()
# d["lambda"] = (2,3)
# d["b"] = (5,6)
rbf_d["reg_lambda"] = tuple(10**(-i) for i in range(16))
rbf_d["gamma"]=  tuple(10**(-i) for i in range(-2,16))



keys = rbf_d.keys()
values = rbf_d.values()

search_grid = list(itertools.product(*values))


# parameter d
d = 50
lowest_err = sys.maxsize
for values in search_grid:
    temp_d = {k:v for k,v in zip(keys, values)}
    gamma =temp_d["gamma"]
    reg_lambda = temp_d["reg_lambda"]
    # K = poly_kernel(xs, d)
    K = rbf_kernel(xs, gamma)
    err_loo = 0
    for i in range(n):
        K_loo = np.delete(K,i, 0) # delete i row 
        K_loo = np.delete(K_loo, i, 1)# delete i column 
        alpha = kernelRidgeRegression(K_loo, np.delete(ys, i, 0), reg_lambda)
        K_left = K[i]
        K_left = np.delete(K_left, i, 0)
        y_predict = predict(K_left, alpha)
        err_loo += (y_predict - ys[i])**2
    err_loo = (1/n) * err_loo
    if err_loo < lowest_err:
        lowest_err = err_loo
        best_parameter = temp_d
print("lowest loo validation error: ", lowest_err)
print(best_parameter)
# Out:
# lowest loo validation error:  0.438602246442243
# {'reg_lambda': 1e-15, 'gamma': 10}

# %%
poly_d = dict()
poly_d["reg_lambda"] = tuple(1*10**(-i) for i in range(16))
poly_d["d"]= tuple(range(30))




keys = poly_d.keys()
values = poly_d.values()

search_grid = list(itertools.product(*values))


# parameter d
d = 50
lowest_err = sys.maxsize
for values in search_grid:
    temp_d = {k:v for k,v in zip(keys, values)}
    d =temp_d["d"]
    reg_lambda = temp_d["reg_lambda"]
    # K = poly_kernel(xs, d)
    K = poly_kernel(xs, d)
    err_loo = 0
    for i in range(n):
        K_loo = np.delete(K,i, 0) # delete i row 
        K_loo = np.delete(K_loo, i, 1)# delete i column 
        alpha = kernelRidgeRegression(K_loo, np.delete(ys, i, 0), reg_lambda)
        K_left = K[i]
        K_left = np.delete(K_left, i, 0)
        y_predict = predict(K_left, alpha)
        err_loo += (y_predict - ys[i])**2
    err_loo = (1/n) * err_loo
#     print(temp_d, err_loo)
    if err_loo < lowest_err:
        lowest_err = err_loo
        best_parameter = temp_d
print("lowest loo validation error: ", lowest_err)
print(best_parameter)
# Out:
# lowest loo validation error:  0.41134601409844773
# {'reg_lambda': 1e-05, 'd': 27}

# %%
d = dict()
d["a"] =1
for key, value in d.items():
    print(key, value)
300*0.05

np.linspace(1,0)
# Out:
# a 1
# array([1.        , 0.97959184, 0.95918367, 0.93877551, 0.91836735,
#        0.89795918, 0.87755102, 0.85714286, 0.83673469, 0.81632653,
#        0.79591837, 0.7755102 , 0.75510204, 0.73469388, 0.71428571,
#        0.69387755, 0.67346939, 0.65306122, 0.63265306, 0.6122449 ,
#        0.59183673, 0.57142857, 0.55102041, 0.53061224, 0.51020408,
#        0.48979592, 0.46938776, 0.44897959, 0.42857143, 0.40816327,
#        0.3877551 , 0.36734694, 0.34693878, 0.32653061, 0.30612245,
#        0.28571429, 0.26530612, 0.24489796, 0.2244898 , 0.20408163,
#        0.18367347, 0.16326531, 0.14285714, 0.12244898, 0.10204082,
#        0.08163265, 0.06122449, 0.04081633, 0.02040816, 0.        ])

# %%
def search_v(xs, ys, predict_d, B=300):
    five_perc_bound =  (int)(B*0.05)
    five_percent_v  = []
    nighty_five_percent_v = []
    for i in range(len(xs)):
        x = xs[i]
        y = ys[i]
        y_preds = predict_d[i] # get an array of predictions
        
        y_preds = np.sort(y_preds)
        v = np
        for j in range(len(xs)):
            # append the value before violation 
            # TODO: v values. linspace
            
#             print(y_preds[j])
#             print(five_perc_bound)
#             if y_preds[j] > five_perc_bound: # predictions for x_rand_idx
            five_percent_v.append(y_preds[five_perc_bound])
        for j in range(len(xs)-1, -1, -1):
            # add the first 
#             if y_preds[j] <= nf_perc_bound:
            nighty_five_percent_v.append(y_preds[-five_perc_bound])
    return five_percent_v, nighty_five_percent_v

# %%
# A3 b1

# trial and plot
K = rbf_kernel(xs,10)
alpha = kernelRidgeRegression(K, ys, reg_lambda = 1e-15)
predict_ys = predict(K, alpha)

plt.plot(xs, ys,  label = "True ys")
plt.plot(xs, predict_ys, label = "prediction")
plt.scatter(xs, ys, label = "original data")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("A3b rbf kernel")

# %%
xs_idx = np.array(list(range(30)))

# %%
# A3 c1
B = 300




# confidence 
predict_d = dict() # key: x value: predictions
for b in range(B):
    rand_idx = np.random.randint(30, size = n)
    xs_bs = xs[rand_idx]
    xs_rand_idx = xs_idx[rand_idx]
    K = rbf_kernel(xs_bs,10)
    alpha = kernelRidgeRegression(K, ys, reg_lambda = 1e-15)
    predict_ys = predict(K, alpha)
    idx = 0
    # append prediction follow the random order
    for x_idx in xs_rand_idx:
        if x_idx not in predict_d:
            predict_d[x_idx] = [predict_ys[idx]]
        else:
            predict_d[x_idx].append(predict_ys[idx])
        idx += 1
five_percent_v, nighty_five_percent_v  = search_v(xs, ys, predict_d)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-45216cdbe2b5> in <module>
#      22             predict_d[x_idx].append(predict_ys[idx])
#      23         idx += 1
# ---> 24 five_percent_v, nighty_five_percent_v  = search_v(xs, ys, predict_d)
#
# <ipython-input-17-5036043f89bd> in search_v(xs, ys, predict_d, B)
#      22             # add the first
#      23 #             if y_preds[j] <= nf_perc_bound:
# ---> 24             nighty_five_percent_v.append(y_preds[nf_perc_bound])
#      25     return five_percent_v, nighty_five_percent_v
#
# IndexError: index 285 is out of bounds for axis 0 with size 281

# %%
nighty_five_percent_v
# Out:
# [-2.89794921875,
#  -2.89794921875,
#  -2.90625,
#  -2.90625,
#  -2.9375,
#  -3.0,
#  -3.0,
#  -3.0,
#  -3.0,
#  -3.0,
#  -3.068359375,
#  -3.125,
#  -3.125,
#  -3.125,
#  -3.125,
#  -3.375,
#  -3.375,
#  -3.375,
#  -3.421875,
#  -3.5,
#  -3.5,
#  -3.5,
#  -3.53125,
#  -3.5703125,
#  -3.609375,
#  -3.625,
#  -3.75,
#  -3.78125,
#  -4.125,
#  -4.25,
#  -2.875,
#  -2.875,
#  -2.921875,
#  -3.0,
#  -3.0,
#  -3.125,
#  -3.1640625,
#  -3.1796875,
#  -3.234375,
#  -3.25,
#  -3.3125,
#  -3.3359375,
#  -3.375,
#  -3.40625,
#  -3.40625,
#  -3.4375,
#  -3.4375,
#  -3.5,
#  -3.5,
#  -3.546875,
#  -3.5625,
#  -3.56640625,
#  -3.625,
#  -3.671875,
#  -3.6875,
#  -3.71875,
#  -3.7734375,
#  -3.79296875,
#  -3.828125,
#  -3.9375,
#  -2.75,
#  -2.75,
#  -2.75,
#  -2.75,
#  -2.873046875,
#  -3.0,
#  -3.05859375,
#  -3.203125,
#  -3.21875,
#  -3.25,
#  -3.25,
#  -3.25,
#  -3.25,
#  -3.32421875,
#  -3.421875,
#  -3.4375,
#  -3.5,
#  -3.53125,
#  -3.5625,
#  -3.59375,
#  -3.625,
#  -3.625,
#  -3.75,
#  -3.75,
#  -3.78125,
#  -3.8125,
#  -3.8125,
#  -3.8203125,
#  -3.9375,
#  -3.9375,
#  -2.71875,
#  -2.75,
#  -2.75,
#  -2.828125,
#  -2.875,
#  -2.9375,
#  -3.0,
#  -3.0,
#  -3.03125,
#  -3.046875,
#  -3.0625,
#  -3.125,
#  -3.125,
#  -3.125,
#  -3.1875,
#  -3.25,
#  -3.25,
#  -3.25,
#  -3.375,
#  -3.46875,
#  -3.5,
#  -3.5,
#  -3.53125,
#  -3.59375,
#  -3.59375,
#  -3.71875,
#  -3.75,
#  -3.8125,
#  -3.8125,
#  -3.875,
#  -2.6875,
#  -2.71875,
#  -2.8125,
#  -2.8125,
#  -2.8203125,
#  -2.94580078125,
#  -3.0,
#  -3.0625,
#  -3.125,
#  -3.15625,
#  -3.21875,
#  -3.21875,
#  -3.21875,
#  -3.25,
#  -3.25,
#  -3.25,
#  -3
,
#  -3.4375,
#  -3.5,
#  -3.5,
#  -3.5625,
#  -3.5625,
#  -3.625,
#  -3.625,
#  -3.6875,
#  -3.7421875,
#  -3.75,
#  -3.8125,
#  -3.875,
#  -4.0,
#  -4.0,
#  -4.0,
#  -4.0,
#  -4.0,
#  -2.65625,
#  -2.6875,
#  -2.8125,
#  -2.921875,
#  -2.9765625,
#  -3.0,
#  -3.03125,
#  -3.10546875,
#  -3.359375,
#  -3.375,
#  -3.3984375,
#  -3.421875,
#  -3.421875,
#  -3.4375,
#  -3.4375,
#  -3.4453125,
#  -3.451171875,
#  -3.51171875,
#  -3.5234375,
#  -3.53125,
#  -3.60595703125,
#  -3.625,
#  -3.625,
#  -3.625,
#  -3.640625,
#  -3.75,
#  -3.828125,
#  -3.837890625,
#  -3.859375,
#  -4.25,
#  -2.416015625,
#  -2.419921875,
#  -2.421875,
#  -2.65625,
#  -2.78125,
#  -2.84375,
#  -2.875,
#  -2.875,
#  -2.875,
#  -2.875,
#  -3.0,
#  -3.0,
#  -3.0,
#  -3.078125,
#  -3.125,
#  -3.1640625,
#  -3.1875,
#  -3.1875,
#  -3.203125,
#  -3.234375,
#  -3.328125,
#  -3.375,
#  -3.375,
#  -3.375,
#  -3.375,
#  -3.5859375,
#  -3.6015625,
#  -3.75,
#  -4.0625,
#  -4.0703125,
#  -3.1328125,
#  -3.15625,
#  -3.171875,
#  -3.25,
#  -3.25,
#  -3.40234375,
#  -3.4140625,
#  -3.43505859375,
#  -3.4375,
#  -3.4375,
#  -3.4375,
#  -3.4375,
#  -3.4375,
#  -3.4375,
#  -3.5,
#  -3.5,
#  -3.5,
#  -3.640625,
#  -3.6875,
#  -3.75,
#  -3.75,
#  -3.75,
#  -3.75,
#  -3.8125,
#  -3.84375,
#  -3.8671875,
#  -3.875,
#  -3.8828125,
#  -3.96875,
#  -4.2880859375]

# %%
plt.plot(xs,five_percent_v )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-85daf2970b2e> in <module>
# ----> 1 plt.plot(xs,five_percent_v )
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (30,) and (0,)

# %%
# A3 b2
# trial and plot
K = poly_kernel(xs, 27)
alpha = kernelRidgeRegression(K, ys, reg_lambda = 1e-5)
predict_ys = predict(K, alpha)

plt.plot(xs, ys,label = "True ys")
plt.plot(xs, predict_ys, label = "prediction")
plt.scatter(xs, ys, label = "original data")
# plt.plot(xs, ys, marker = 'o', label = "data points")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("A3b poly kernel")
plt.show()

# %%
np.linspace(0,0.5)

# %%
search_v(predict_ys)
# plot xs, v

# %%
def hoeffding( num_samples, num_correct, a= 0, b= 1, delta = 0.05):
    rhs = math.sqrt( (b-a)**2*math.log(2/delta, math.e)/(2* num_samples) )
    mu_conf_interval = ( -rhs+test_error ,  rhs+test_error )
    return mu_conf_interval

# %%
# testing


# simple test
x1 = np.array([[1,2],[3,4]])
# x2 = np.array([3,4])

K = poly_kernel(x1, 2)
# K = rbf_kernel(x1, 2)

alpha = kernelRidgeRegression(K, np.array([3,4]))
predict(K[1], alpha)
